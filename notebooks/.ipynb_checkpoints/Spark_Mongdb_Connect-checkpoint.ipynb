# %% [markdown]
# # 논문 네트워크 시각화 프로젝트 전처리 디벨롭

# %% [markdown]
# ### 문제점
# #### 1. mongodb 와 spark 연동 실패 -> spark dataframe이 아닌 pandas dataframe으로 불러와서 변환하는 추가작업이 필요했음

# %%
pip install pymongo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### 1. Mongodb -> Spark 연동 실패
#
# ##### 문제점 1. 사용자 계정 및 비밀번호 노출
# ##### 문제점 2. bson -> pandas dataframe -> spark DataFrame 변환하는 방식으로 진행하여 효율성 감소
# ##### 문제점 3. 문제점 2의 형식으로 진행시 -> 리스트 형태의 값들이 전부 스트링 형태로 저장되는 문제 발생

# %%
from pymongo import MongoClient

client = MongoClient("mongodb://root:1234@mongodb:27017/admin")
db_names = client.list_database_names()
print("Available databases:", db_names)
db = client['kci_trained_api']

collection_names = db.list_collection_names()
print("Available collection_names:", collection_names)
# Out:
# Available databases: ['Egg_', 'admin', 'category', 'config', 'kci_AuGraph', 'kci_api', 'kci_author_info', 'kci_ccGraph', 'kci_trained_api', 'local', 'mydb', 'reference_map']
# Available collection_names: ['kci_trained_202309', 'kci_trained_202309_dev', 'kci_trained_202310']

# %%
def get_kci_data(df_name):
    print('Get',df_name,"!")
    kci_db_name = "kci_trained_api"
    kci_db = client[kci_db_name]
    kci_data = list(kci_db[df_name].find({}))
    
    pandas_df = pd.DataFrame(kci_data)
    pandas_df = pandas_df[['articleID','titleEng','abstractEng','journalID','pubYear','refereceTitle']]
    pandas_df = pandas_df.astype(str)

    spark_df = spark.createDataFrame(pandas_df)
#    spark_df = spark_df.withColumn("keywords", parse_lists_udf(spark_df['refereceTitle']))

    return spark_df

df_name = "kci_trained_202309"
temp = get_kci_data(df_name)
temp.printSchema()

# %% [markdown]
# ### 문제 해결

# %% [markdown]
# ##### 민감정보 노출 -> config.py를 따로 구성하여 코드 상에서 나타지 않게 함.
# ##### jars.packages 를 사용하여 MongoDB 연동.

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import StringType, ArrayType, StructType, StructField
from pyspark.sql.functions import explode, col, trim, collect_set, count, size

import config

# %%
spark = SparkSession.builder\
    .config("spark.jars.packages", "org.mongodb.spark:mongo-spark-connector_2.12:3.0.0")\
    .appName("kci").getOrCreate()

# %%
def parse_list(value):
    return ast.literal_eval(value) if value else []
    
kci_api_uri = f"mongodb://{config.mongo_user}:{config.mongo_pass}@mongodb:27017/kci_trained_api.kci_trained_202309?authSource=admin"

schema = StructType([
    StructField("articleID", StringType(), True),
    StructField("titleEng", StringType(), True),
    StructField("abstractEng", StringType(), True),
    StructField("journalID", StringType(), True),
    StructField("pubYear", StringType(), True),
    StructField("refereceTitle", StringType(), True),
    StructField("class", StringType(), True)

])

df = spark.read.format("mongo") \
    .option("uri", kci_api_uri) \
    .schema(schema)\
    .load()

# 문자열 -> 리스트 변환
parse_list_udf = udf(parse_list, ArrayType(StringType()))
df = df.withColumn("refereceTitle", parse_list_udf(df["refereceTitle"]))

df.printSchema()
df.show()

# %% [markdown]
# ##### 실제 리스트 값의 유지 확인을 위한 저장

# %%
save_uri = f"mongodb://{config.mongo_user}:{config.mongo_pass}@mongodb:27017/kci_trained_api.kci_trained_202309_dev?authSource=admin"

df.write.format("mongo") \
    .option("uri", save_uri) \
    .mode("append") \
    .save()

# %% [markdown]
# # 리스트로 저장 된 데이터 불러오기

# %%
kci_api_uri_dev = f"mongodb://{config.mongo_user}:{config.mongo_pass}@mongodb:27017/kci_trained_api.kci_trained_202309_dev?authSource=admin"

schema = StructType([
    StructField("articleID", StringType(), True),
    StructField("titleEng", StringType(), True),
    StructField("abstractEng", StringType(), True),
    StructField("journalID", StringType(), True),
    StructField("pubYear", StringType(), True),
    StructField("refereceTitle", ArrayType(StringType()), True),
    StructField("class", StringType(), True)
])

df = spark.read.format("mongo") \
    .option("uri", kci_api_uri_dev) \
    .load()

df.printSchema()
# Out:
# root
#  |-- _id: struct (nullable = true)
#  |    |-- oid: string (nullable = true)
#  |-- abstractEng: string (nullable = true)
#  |-- articleID: string (nullable = true)
#  |-- class: string (nullable = true)
#  |-- journalID: string (nullable = true)
#  |-- pubYear: string (nullable = true)
#  |-- refereceTitle: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- titleEng: string (nullable = true)

# %% [markdown]
# # Article 간의 연관관계 생성시 문제

# %% [markdown]
# ### 기존 방법 : reference Map을 사용하여 연관관계를 생성하는 함수
# ##### 문제점
# 1. 모든 데이터가 들어가 있는 DataFrame에 Join을 하게 되면서 연관관계 생성 시 불필요한 데이터도 연산에 사용되는 문제
# 2. 기존 방식은 reference Map의 형식이 리스트로 되어 있어 join후 리스트 처리에 대한 추가적인 연산이 들어가는 문제 -> 비용 증가

# %%
def merge_origin_new_df(origin_df, new_df, reference_df):
    print('Merge Progress!')

    union_df = origin_df.union(new_df)
    merged_df = union_df.join(reference_df, array_contains(union_df.refereceTitle, reference_df.reference_title), "left")
    merged_df = merged_df.drop("reference_title")
    return merged_df

def process_grouped_dataframe(input_df):
    print('Final Progress!')
    
    grouped_df = input_df.groupBy("articleID").agg(
    F.first("titleEng").alias("titleEng"),
    F.first("abstractEng").alias("abstractEng"),
    F.first("journalID").alias("journalID"),
    F.first("pubYear").alias("pubYear"),
    F.first("refereceTitle").alias("refereceTitle"),
    F.first("keys").alias("keys_list"),
    F.first("ems").alias("ems_list"),
    collect_list("article_list").alias("article_list")
    )

    # "article_list" 컬럼에서 중복 제거 및 고유 값으로 변환하는 함수 정의
    @udf(ArrayType(StringType()))
    def remove_duplicates_and_make_unique(arr):
        unique_values = set()
        for sublist in arr:
            for item in sublist:
                unique_values.add(item)
        return list(unique_values)

    grouped_df = grouped_df.withColumn("article_list", remove_duplicates_and_make_unique("article_list"))

    # "articleID"가 "article_list" 컬럼 내에 있는 경우 제거하는 함수 정의
    @udf(ArrayType(StringType()))
    def remove_article_id_from_list(article_list, article_id):
        return [item for item in article_list if item != article_id]

    # "articleID"가 "article_list" 컬럼 내에 있는 경우 제거
    grouped_df = grouped_df.withColumn("article_list",remove_article_id_from_list("article_list", grouped_df["articleID"]))

    return grouped_df

# %% [markdown]
# # Reference Map 생성

# %% [markdown]
# ### refereceTitle 을 기준으로 articleID explode 및 중복제거

# %%
expl_df = df.select(explode(col("refereceTitle")).alias("referenceTitle"),"articleID")
a = expl_df.count()
expl_df = expl_df.dropDuplicates()
b = expl_df.count()
print(f'{a-b}개 제거')
expl_df.show()
# Out:
# 578개 제거
# +----------------------------------+------------+
# |                    referenceTitle|   articleID|
# +----------------------------------+------------+
# |              Frames of Mind: T...|ART001627307|
# |              A Survey of Colla...|ART001687100|
# |              Bayesian Networks...|ART001667194|
# |              Learning from Imb...|ART001921082|
# |              NCQ vs. I/O sched...|ART001900163|
# |              Eli: Bare- Metal ...|ART001858224|
# |투사성과 재탐색을 이용한 결정적...|ART001844988|
# | 미래 인터넷을 위한 네트워크 가...|ART001609147|
# |              Translation camer...|ART001586329|
# |              Efficient context...|ART001545207|
# |              A survey on senso...|ART001545240|
# |              A Low-Bandwidth N...|ART001545258|
# |              Effects on the Ch...|ART001545277|
# |              Texture-based seg...|ART001558044|
# |              Classification al...|ART001558044|
# |              The Rate-Monotoni...|ART001576240|
# ...

# %% [markdown]
# ### 레퍼런스 맵 질의

# %%
expl_df.createOrReplaceTempView("refer")
result = spark.sql("SELECT * FROM refer WHERE articleID = 'ART001627307'")
result.show()
# Out:
# +---------------------------------+------------+
# |                   referenceTitle|   articleID|
# +---------------------------------+------------+
# |             Frames of Mind: T...|ART001627307|
# |             Content-Based Rec...|ART001627307|
# |             A Collaborative F...|ART001627307|
# |이러닝 적용을 위한 뇌파기반 인...|ART001627307|
# |             A new similarity ...|ART001627307|
# |             Gifts Differing: ...|ART001627307|
# |             Hybrid Content an...|ART001627307|
# |             Analysis of Recom...|ART001627307|
# |             Design and Implem...|ART001627307|
# |             An Algorithmic Fr...|ART001627307|
# |지능형 튜토링과 게임 기반 학습...|ART001627307|
# |콘텐츠 타입을 활용한 적응적 협...|ART001627307|
# |             Affective e-Learn...|ART001627307|
# |             Analyzing facial ...|ART001627307|
# |             Experiential Lear...|ART001627307|
# +---------------------------------+------------+

# %%
#expl_df.limit(2).show(truncate=False)
result = spark.sql("SELECT * FROM refer WHERE referenceTitle = 'A Survey of Collaborative Filtering Techniques'")
result.show()
# Out:
# +--------------------+------------+
# |      referenceTitle|   articleID|
# +--------------------+------------+
# |A Survey of Colla...|ART001687100|
# |A Survey of Colla...|ART001652287|
# |A Survey of Colla...|ART002128387|
# |A Survey of Colla...|ART001718457|
# |A Survey of Colla...|ART002254817|
# +--------------------+------------+

# %% [markdown]
# ### 공백을 제거하여 비교하였을 때 중복된 논문 제거

# %%
expl_rm_df = expl_df.withColumn("referenceTitle", trim(col("referenceTitle"))).dropDuplicates(["articleID", "referenceTitle"])
print(expl_df.count())
print(expl_rm_df.count())
unique_count = expl_rm_df.select("referenceTitle").distinct().count()
print(f'{unique_count} 유니크 값')
expl_rm_df.show()
# Out:
# 128258
# 128258
# 103969 유니크한 값
# +----------------------------------+------------+
# |                    referenceTitle|   articleID|
# +----------------------------------+------------+
# |              Software Requirem...|ART001652195|
# |              Segmentation for ...|ART001642115|
# |              Virtual machine-a...|ART001685500|
# |              Comparison of Has...|ART001685507|
# |              A comparative stu...|ART001685515|
# |              Novel Approaches ...|ART001687112|
# |              Market of Mobile ...|ART001667210|
# |              Amoba arinc 653 s...|ART001667208|
# |              MapReduce:simplif...|ART001900121|
# |              High performance ...|ART001900157|
# |                 Space-Time coding|ART001867865|
# |             Structural SVMs 및...|ART001867939|
# |              Blue tooth-based ...|ART001867952|
# |              A survey on appli...|ART001858226|
# |              Fast and Enhanced...|ART001848997|
# ...

# %% [markdown]
# ### 연관관계 테이블 생성

# %% [markdown]
# 1. 레퍼런스 맵을 리스트 x
# 2. 필요한 컬럼만 선정 후 조인

# %%
df_exploded1 = df.select("articleID", explode(col("refereceTitle")).alias("referenceTitle"))
df_exploded2 = df.select(col("articleID").alias("RelationArticleID"), explode(col("refereceTitle")).alias("referenceTitle2"))

joined_df = df_exploded1.join(df_exploded2, df_exploded1["referenceTitle"] == df_exploded2["referenceTitle2"], "left")
selected_columns = ["articleID", "RelationArticleID"]
joined_df = joined_df.select(selected_columns)
joined_df = joined_df.filter(joined_df["articleID"] != joined_df["RelationArticleID"])

joined_df = joined_df.groupby("articleID").agg(collect_set(col("RelationArticleID")).alias("RelationArticleID"))
joined_df = joined_df.withColumn("length", size(col("RelationArticleID")))
joined_df = joined_df.orderBy("length", ascending=False)

joined_df.show()
# Out:
# +------------+-----------------+
# |   articleID|RelationArticleID|
# +------------+-----------------+
# |ART002591647|     ART002760859|
# |ART002760859|     ART002591647|
# |ART001697710|     ART002014987|
# |ART002014987|     ART001697710|
# |ART001590912|     ART001958981|
# |ART001590912|     ART002368842|
# |ART001958981|     ART001590912|
# |ART001958981|     ART002368842|
# |ART002368842|     ART001590912|
# |ART002368842|     ART001958981|
# |ART001605204|     ART001958990|
# |ART001605204|     ART001931149|
# |ART001605204|     ART001931146|
# |ART001605204|     ART001806261|
# |ART001958990|     ART001605204|
# |ART001958990|     ART001931149|
# |ART001958990|     ART001931146|
# |ART001958990|     ART001806261|
# |ART001931149|     ART001605204|
# |ART001931149|     ART001958990|
# +------------+-----------------+
# only showing top 20 rows

# %% [markdown]
# # 네트워크 그래프 생성

# %%
import networkx as nx

# %%
def generate_and_save_graph(df):
    print("Generate CcGrpah")
    G = nx.Graph()

    for row in df.rdd.collect():
        article_id = row['articleID']
        G.add_node(article_id)

    # 아티클 리스트를 기준으로 엣지(링크)를 추가
    for row in df.rdd.collect():
        article_id = row['articleID']
        article_list = row['RelationArticleID']
        for reference in article_list:
            G.add_edge(article_id, reference)
            
    graphname = "CcGraph.graphml"
    nx.write_graphml(G, graphname)
    print('Saved',graphname)
def load_graph(graph_file):
    print("Loading graph from file:", graph_file)
    G = nx.read_graphml(graph_file)
    print("Graph loaded successfully!")
    return G

# %%
generate_and_save_graph(joined_df)
# Out:
# Generate CcGrpah
# Saved CcGraph.graphml

# %%
loaded_graph = load_graph("CcGraph.graphml")
# Out:
# Loading graph from file: CcGraph.graphml
# Graph loaded successfully!

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(100, 100))
nx.draw(loaded_graph, with_labels=False, node_color='skyblue', node_size=300, edge_color='gray')
plt.title("Connected Graph")
plt.show()
